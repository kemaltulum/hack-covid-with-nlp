# %%
import pickle
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
hashtag_day = "06.04"

# %%
print(len(tweet_vectors_all))
# Out:
# 6790

# %%
X = []
for vecs in tweet_vectors_all:
    if len(vecs) == 0:
        continue
    X.append(np.mean(vecs, axis=0))

X = np.array(X)

# %%
print(X.shape)
# Out:
# (6789, 400)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95, random_state=42)
X_reduced= pca.fit_transform(X)
X_reduced.shape
# Out:
# (6789, 185)

# %%
from sklearn.manifold import TSNE

tsne = TSNE(verbose=1, perplexity=100, random_state=42)
X_embedded = tsne.fit_transform(X)
# Out:
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 6789 samples in 0.258s...
# [t-SNE] Computed neighbors for 6789 samples in 34.203s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6789
# [t-SNE] Computed conditional probabilities for sample 2000 / 6789
# [t-SNE] Computed conditional probabilities for sample 3000 / 6789
# [t-SNE] Computed conditional probabilities for sample 4000 / 6789
# [t-SNE] Computed conditional probabilities for sample 5000 / 6789
# [t-SNE] Computed conditional probabilities for sample 6000 / 6789
# [t-SNE] Computed conditional probabilities for sample 6789 / 6789
# [t-SNE] Mean sigma: 2.011732
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.898064
# [t-SNE] KL divergence after 1000 iterations: 2.308201

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# sns settings
sns.set(rc={'figure.figsize':(15,15)})

# colors
palette = sns.color_palette("bright", 1)

# plot
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], palette=palette)
plt.title('t-SNE with no Labels')
plt.savefig("t-sne_word_vec{}.png".format(hashtag_day))
plt.show()
