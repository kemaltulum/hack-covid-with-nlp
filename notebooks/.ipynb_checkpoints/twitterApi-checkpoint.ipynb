# %% [markdown]
# # Tweet Collection and Storing Them

# %% [markdown]
# * Insert tweets into db with some id, hashing its text and user
#
#
# ### FoxTV Ana Haber Bülteni Hashtag'leri
#
# * 2 Nisan 2020 : #şüpheduymuyorum
# * 3 Nisan 2020 : #duysesimi
# * 4 Nisan 2020 : #
# * 5 Nisan 2020 : #
# * 6 Nisan 2020 : #neyinnesi (Erdoğan Açıklama 19:00)
# * 7 Nisan 2020 : #biralkışda
# * 8 Nisan 2020 : #hepsinitopla
# * 9 Nisan 2020 : #kabuledilemez
# * 10 Nisan 2020 : #neredenbulacağım
#
# * 13 Nisan : #gittimgeldim
# * 14 Nisan : #işaş
# * 15 Nisan : #veresiyedefteri
# * 16 Nisan : #çağrımvar
# * 17 Nisan : #sesverin

# %%
import tweepy
from pprint import pprint
from pymongo import MongoClient
from pymongo.errors import BulkWriteError
import json

# %%
client = MongoClient('mongodb://localhost:27017/')

db = client.covid_hack
tweets_db = db.tweets

tweets_db.find_one()
# Out:
# {'_id': ObjectId('5e8f04f3411c489a86a6e7a2'),
#  'created_at': 'Thu Apr 09 10:10:40 +0000 2020',
#  'id': 1248191593850568709,
#  'id_str': '1248191593850568709',
#  'full_text': 'RT @erdmozvrn: Şu Maaşım\nŞuda Kartım Yavrum..\n\n#Şüpheduymuyorum https://t.co/4hlD0Yc4yC',
#  'truncated': False,
#  'display_text_range': [0, 87],
#  'entities': {'hashtags': [{'text': 'Şüpheduymuyorum', 'indices': [47, 63]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'erdmozvrn',
#     'name': 'Erdem Özveren',
#     'id': 2365427365,
#     'id_str': '2365427365',
#     'indices': [3, 13]}],
#   'urls': [],
#   'media': [{'id': 1245763183685570560,
#     'id_str': '1245763183685570560',
#     'indices': [64, 87],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#     'url': 'https://t.co/4hlD0Yc4yC',
#     'display_url': 'pic.twitter.com/4hlD0Yc4yC',
#     'expanded_url': 'https://twitter.com/erdmozvrn/status/1245763816543191041/video/1',
#     'type': 'photo',
#     'sizes': {'medium': {'w': 640, 'h': 640, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#      'small': {'w': 640, 'h': 640, 'resize': 'fit'}},
#     'source_status_id': 1245763816543191041,
#     'source_status_id_str': '1245763816543191041',
#     'source_user_id': 2365427365,
#     'source_user_id_str': '2365427365'}]},
#  'extended_entities': {'media': [{'id': 1245763183685570560,
#     'id_str': '1245763183685570560',
#     'indices': [64, 87],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#     'url': 'https://t.co/4hlD0Yc4yC',
#     'display_url': 'pic.twitter.com/4hlD0Yc4yC',
#     'expanded_url': 'https://twitter.com/erdmozvrn/status/1245763816543191041/video/1',
#     'type': 'video',
#     'sizes': {'medium': {'w': 640, 'h': 640, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#      'small': {'w': 640, 'h': 640, 'resize': 'fit'}},
#     'source_status_id': 1245763816543191041,
#     'source_status_id_str': '1245763816543191041',
#     'source_user_id': 2365427365,
#     'source_user_id_str': '2365427365',
#     'video_info': {'aspect_ratio': [1, 1],
#      'duration_millis': 36933,
#      'variants': [{'bitrate': 1280000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/vid/640x640/7HDytF09-xhqMm6m.mp4?tag=10'},
#       {'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/vid/480x480/91Je7Pkkg-YLrGiW.mp4?tag=10'},
#       {'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/pl/UuNMIAvU5t6nQ44e.m3u8?tag=10'},
#       {'bitrate': 432000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/vid/320x320/fJpfM6csnBw--pBg.mp4?tag=10'}]},
#     'additional_media_info': {'monetizable': False,
#      'source_user': {'id': 2365427365,
#       'id_str': '2365427365',
#       'name': 'Erdem Özveren',
#       'screen_name': 'erdmozvrn',
#       'location': 'Türkiye',
#       'description': '🇹🇷 Bir kötülük gördüğünüz zaman onu elinizle düzeltin, gücünüz yetmezse dilinizle, ona da gücünüz yetmezse kalben buğz edin. (H.Şerif) @MislamDernegi Baş.',
#       'url': 'https://t.co/AGUWmyWk9l',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/AGUWmyWk9l',
#           'expanded_url': 'http://www.instagram.com/erdemozveren1453',
#           'display_url': 'instagram.com/erdemozveren14…',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 87554,
#       'friends_count': 87,
#       'listed_count': 61,
#       'created_at': 'Fri Feb 28 10:42:23 +0000 2014',
#       'favourites_count': 4725,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 2028,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1110592555115339776/QZnTn086_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1110592555115339776/QZnTn086_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2365427365/1573656064',
#       'profile_link_color': 'E81C4F',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': False,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'}}}]},
#  'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1978326792,
#   'id_str': '1978326792',
#   'name': 'Şükrü TOKLUOĞLU',
#   'screen_name': '38Tokluoglu',
#   'location': 'KAYSERİ-DEVELİ',
#   'description': 'RTE Gönüllüsü & Sadece AK Dostlar Takip Önceliğim& Ayrıca Fenerbahçe li Bir Esnafım',
#   'url': 'https://t.co/ahPDORcy5w',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/ahPDORcy5w',
#       'expanded_url': 'http://www.xn--tokluolu-cgb.com',
#       'display_url': 'tokluoğlu.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4904,
#   'friends_count': 4685,
#   'listed_count': 2,
#   'created_at': 'Mon Oct 21 11:13:46 +0000 2013',
#   'favourites_count': 9898,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 13804,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1142698263000301569/zr9lglPr_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1142698263000301569/zr9lglPr_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1978326792/1500151726',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Thu Apr 02 17:23:33 +0000 2020',
#   'id': 1245763816543191041,
#   'id_str': '1245763816543191041',
#   'full_text': 'Şu Maaşım\nŞuda Kartım Yavrum..\n\n#Şüpheduymuyorum https://t.co/4hlD0Yc4yC',
#   'truncated': False,
#   'display_text_range': [0, 48],
#   'entities': {'hashtags': [{'text': 'Şüpheduymuyorum', 'indices': [32, 48]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1245763183685570560,
#      'id_str': '1245763183685570560',
#      'indices': [49, 72],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#      'url': 'https://t.co/4hlD0Yc4yC',
#      'display_url': 'pic.twitter.com/4hlD0Yc4yC',
#      'expanded_url': 'https://twitter.com/erdmozvrn/status/1245763816543191041/video/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'small': {'w': 640, 'h': 640, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1245763183685570560,
#      'id_str': '1245763183685570560',
#      'indices': [49, 72],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1245763183685570560/pu/img/qyAgAd7g7ALW-ekf.jpg',
#      'url': 'https://t.co/4hlD0Yc4yC',
#      'display_url': 'pic.twitter.com/4hlD0Yc4yC',
#      'expanded_url': 'https://twitter.com/erdmozvrn/status/1245763816543191041/video/1',
#      'type': 'video',
#      'sizes': {'medium': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#       'small': {'w': 640, 'h': 640, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [1, 1],
#       'duration_millis': 36933,
#       'variants': [{'bitrate': 1280000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/vid/640x640/7HDytF09-xhqMm6m.mp4?tag=10'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/vid/480x480/91Je7Pkkg-YLrGiW.mp4?tag=10'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/pl/UuNMIAvU5t6nQ44e.m3u8?tag=10'},
#        {'bitrate': 432000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1245763183685570560/pu/vid/320x320/fJpfM6csnBw--pBg.mp4?tag=10'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2365427365,
#    'id_str': '2365427365',
#    'name': 'Erdem Özveren',
#    'screen_name': 'erdmozvrn',
#    'location': 'Türkiye',
#    'description': '🇹🇷 Bir kötülük gördüğünüz zaman onu elinizle düzeltin, gücünüz yetmezse dilinizle, ona da gücünüz yetmezse kalben buğz edin. (H.Şerif) @MislamDernegi Baş.',
#    'url': 'https://t.co/AGUWmyWk9l',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/AGUWmyWk9l',
#        'expanded_url': 'http://www.instagram.com/erdemozveren1453',
#        'display_url': 'instagram.com/erdemozveren14…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87554,
#    'friends_count': 87,
#    'listed_count': 61,
#    'created_at': 'Fri Feb 28 10:42:23 +0000 2014',
#    'favourites_count': 4725,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2028,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1110592555115339776/QZnTn086_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1110592555115339776/QZnTn086_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2365427365/1573656064',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 915,
#   'favorite_count': 4457,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'tr'},
#  'is_quote_status': False,
#  'retweet_count': 915,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'tr',
#  'hashtag_id': '#şüpheduymuyorum'}

# %%
file = open('keys.json')
key_dict = json.loads(file.read())
file.close()

# %%
auth = tweepy.OAuthHandler(key_dict['consumer_key'], key_dict['consumer_secret'])
auth.set_access_token(key_dict['access_token'], key_dict['access_token_secret'])

api = tweepy.API(auth)

# %%
def reshape_tweet(tweet, hashtag_id):
    tweet['hashtag_id'] = hashtag_id
    return tweet

# %%
searched_hashtags = ['#şüpheduymuyorum', '#duysesimi', '#biralkısda', '#neyinnesi', "#biralkışda", '#hepsinitopla', '#kabuledilemez', '#gittimgeldim', '#işaş', '#veresiyedefteri', '#çağrımvar', '#cağrımvar']

# %%
tweet_search_continue = True
check_all_for_dup = True
hashtag_id = '#sesverin'
max_id = None
request_number = 0

# %%
f = open('conflicts.txt', 'a+')

while tweet_search_continue:
    
    print("Request {}".format(request_number))
    
    request_number += 1
    
    tweets = api.search(q=hashtag_id, count=100, lang="tr", max_id=max_id, tweet_mode="extended")
    
    if len(tweets) == 0:
        print("No tweets fetched")
        break
    
    tweets = [tweet._json for tweet in tweets]

    print("Number of tweets {}".format(len(tweets)))
    
    tweets_filtered = []
    for tweet in tweets:
        
        # Check if it is a RT, if RT do no include
        if tweet['full_text'].startswith('RT'):
            continue
        
        no_conflict = True
        
        for hashtag in searched_hashtags:
            if hashtag in tweet['full_text']:
                print("Hashtag {} found in tweet {}".format(hashtag, tweet['id']))
                found = tweets_db.find_one({'id': tweet['id']})
                if found:
                    print("{}:{}:{}".format(hashtag_id, hashtag,tweet['id']), file=f)
                    no_conflict = False
        if no_conflict:
            tweets_filtered.append(tweet)
    
    if len(tweets_filtered) == 0:
        # Means all the fetched tweets are unfiltered as of conflict
        print("No tweets to write database")
        
        last_tweet = tweets[len(tweets)-1]
        max_id = last_tweet['id'] - 1
    
    else:
        print("{} tweets written to db".format(len(tweets_filtered)))
        try:
            tweets_db.insert_many([reshape_tweet(tweet, hashtag_id) for tweet in tweets_filtered])
        except BulkWriteError as bwe:
            pprint(bwe.details)
            raise

        last_tweet = tweets_filtered[len(tweets_filtered)-1]
        max_id = last_tweet['id'] - 1

f.close()
# Out:
# Request 1
# Number of tweets 99
# Hashtag #cağrımvar found in tweet 1251223605268054016
# 18 tweets written to db
# Request 2
# Number of tweets 94
# 12 tweets written to db
# Request 3
# Number of tweets 86
# 12 tweets written to db
# Request 4
# Number of tweets 100
# 18 tweets written to db
# Request 5
# Number of tweets 96
# 18 tweets written to db
# Request 6
# Number of tweets 96
# 16 tweets written to db
# Request 7
# Number of tweets 99
# 17 tweets written to db
# Request 8
# Number of tweets 96
# 12 tweets written to db
# Request 9
# Number of tweets 95
# 23 tweets written to db
# Request 10
# Number of tweets 89
# 24 tweets written to db
# Request 11
# Number of tweets 97
# 22 tweets written to db
# Request 12
# Number of tweets 95
# 17 tweets written to db
# Request 13
# Number of tweets 95
# 24 tweets written to db
# Request 14
# Number of tweets 100
# 21 tweets written to db
# Request 15
# Number of tweets 92
# 17 tweets written to db
# Request 16
# Number of tweets 98
# 22 tweets written to db
# Request 17
# Number of tweets 98
# 23 tweets written to db
# Request 18
# Number of tweets 100
# 23 tweets written to db
# Request 19
# Number of tweets 100
# 27 tweets written to db
# Request 20
# Number of tweets 89
# 16 tweets written to db
# Request 21
# Number of tweets 100
# 18 tweets written to db
# Request 22
# Number of tweets 85
# 13 tweets written to db
# Request 23
# Number of tweets 87
# 15 tweets written to db
# Request 24
# Number of tweets 100
# 16 tweets written to db
# Request 25
# Number of tweets 95
# 17 tweets written to db
# Request 26
# Number of tweets 94
# 22 tweets written to db
# Request 27
# Number of tweets 100
# 31 tweets written to db
# Request 28
# Number of tweets 95
# 17 tweets written to db
# Request 29
# Number of tweets 100
# 19 tweets written to db
# Request 30
# Number of tweets 100
# 24 tweets written to db
# Request 31
# Number of tweets 100
# 27 tweets written to db
# Request 32
# Number of tweets 100
# 19 tweets written to db
# Request 33
# Number of tweets 92
# 18 tweets written to db
# Request 34
# Number of tweets 91
# 28 tweets written to db
# Request 35
# Number of tweets 97
# 23 tweets written to db
# Request 36
# Number of tweets 92
# 15 tweets written to db
# Request 37
# Number of tweets 92
# 23 tweets written to db
# Request 38
# Number of tweets 90
# 21 tweets written to db
# Request 39
# Number of tweets 87
# 13 tweets written to db
# Request 40
# Number of tweets 83
# 24 tweets written to db
# Request 41
# Number of tweets 93
# 14 tweets written to db
# Request 42
# Number of tweets 91
# 17 tweets written to db
# Request 43
# Number of tweets 100
# 26 tweets written to db
# Request 44
# Number of tweets 100
# 22 tweets written to db
# Request 45
# Number of tweets 95
# 25 tweets written to db
# Request 46
# Number of tweets 100
# Hashtag #veresiyedefteri found in tweet 1251201888890036229
# 29 tweets written to db
# Request 47
# Number of tweets 100
# 50 tweets written to db
# Request 48
# Number of tweets 94
# Hashtag #duysesimi found in tweet 1251201015665344512
# 44 tweets written to db
# Request 49
# Number of tweets 96
# 33 tweets written to db
# Request 50
# Number of tweets 97
# 46 tweets written to db
# Request 51
# Number of tweets 91
# 45 tweets written to db
# Request 52
# Number of tweets 96
# 37 tweets written to db
# Request 53
# Number of tweets 92
# 37 tweets written to db
# Request 54
# Number of tweets 83
# 35 tweets written to db
# Request 55
# Number of tweets 91
# 48 tweets written to db
# Request 56
# Number of tweets 98
# 60 tweets written to db
# Request 57
# Number of tweets 88
# Hashtag #veresiyedefteri found in tweet 1251198151270293505
# 58 tweets written to db
# Request 58
# Number of tweets 98
# 60 tweets written to db
# Request 59
# Number of tweets 96
# 51 tweets written to db
# Request 60
# Number of tweets 90
# 42 tweets written to db
# Request 61
# Number of tweets 100
# Hashtag #cağrımvar found in tweet 1251197224748531712
# 47 tweets written to db
# Request 62
# Number of tweets 96
# Hashtag #veresiyedefteri found in tweet 1251196636069539841
# 53 tweets written to db
# Request 63
# Number of tweets 100
# Hashtag #veresiyedefteri found in tweet 1251196636069539841
# 49 tweets written to db
# Request 64
# Number of tweets 89
# Hashtag #veresiyedefteri found in tweet 1251196377029378049
# 52 tweets written to db
# Request 65
# Number of tweets 98
# 43 tweets written to db
# Request 66
# Number of tweets 100
# 54 tweets written to db
# Request 67
# Number of tweets 86
# 48 tweets written to db
# Request 68
# Number of tweets 95
# 43 tweets written to db
# Request 69
# Number of tweets 89
# 49 tweets written to db
# Request 70
# Number of tweets 86
# 44 tweets written to db
# Request 71
# Number of tweets 96
# 53 tweets written to db
# Request 72
# Number of tweets 88
# 30 tweets written to db
# Request 73
# Number of tweets 95
# 37 tweets written to db
# Request 74
# Number of tweets 97
# 29 tweets written to db
# Request 75
# Number of tweets 96
# 29 tweets written to db
# Request 76
# Number of tweets 94
# 40 tweets written to db
# Request 77
# Number of tweets 100
# 32 tweets written to db
# Request 78
# Number of tweets 78
# 26 tweets written to db
# Request 79
# Number of tweets 100
# 39 tweets written to db
# Request 80
# Number of tweets 97
# Hashtag #çağrımvar found in tweet 1251191094261551105
# 39 tweets written to db
# Request 81
# Number of tweets 100
# 53 tweets written to db
# Request 82
# Number of tweets 100
# 57 tweets written to db
# Request 83
# Number of tweets 96
# 59 tweets written to db
# Request 84
# Number of tweets 98
# Hashtag #çağrımvar found in tweet 1251190085774725124
# 60 tweets written to db
# Request 85
# Number of tweets 92
# 49 tweets written to db
# Request 86
# Number of tweets 97
# 53 tweets written to db
# Request 87
# Number of tweets 95
# 57 tweets written to db
# Request 88
# Number of tweets 85
# 52 tweets written to db
# Request 89
# Number of tweets 87
# 52 tweets written to db
# Request 90
# Number of tweets 89
# 50 tweets written to db
# Request 91
# Number of tweets 80
# 52 tweets written to db
# Request 92
# Number of tweets 99
# 72 tweets written to db
# Request 93
# Number of tweets 100
# 66 tweets written to db
# Request 94
# Number of tweets 100
# 68 tweets written to db
# Request 95
# Number of tweets 100
# 69 tweets written to db
# Request 96
# Number of tweets 100
# 79 tweets written to db
# Request 97
# Number of tweets 100
# 60 tweets written to db
# Request 98
# Number of tweets 100
# 75 tweets written to db
# Request 99
# Number of tweets 100
# 64 tweets written to db
# Request 100
# Number of tweets 98
# 73 tweets written to db
# Request 101
# Number of tweets 100
# 70 tweets written to db
# Request 102
# Number of tweets 100
# 73 tweets written to db
# Request 103
# Number of tweets 100
# 78 tweets written to db
# Request 104
# Number of tweets 99
# 69 tweets written to db
# Request 105
# Number of tweets 100
# 78 tweets written to db
# Request 106
# Number of tweets 100
# 59 tweets written to db
# Request 107
# Number of tweets 99
# 66 tweets written to db
# Request 108
# Number of tweets 100
# 60 tweets written to db
# Request 109
# Number of tweets 91
# 55 tweets written to db
# Request 110
# Number of tweets 100
# 55 tweets written to db
# Request 111
# Number of tweets 98
# 71 tweets written to db
# Request 112
# Number of tweets 100
# 76 tweets written to db
# Request 113
# Number of tweets 98
# 67 tweets written to db
# Request 114
# Number of tweets 99
# 73 tweets written to db
# Request 115
# Number of tweets 95
# 73 tweets written to db
# Request 116
# Number of tweets 100
# 86 tweets written to db
# Request 117
# Number of tweets 100
# 94 tweets written to db
# Request 118
# Number of tweets 100
# 92 tweets written to db
# Request 119
# Number of tweets 100
# 85 tweets written to db
# Request 120
# Number of tweets 18
# 17 tweets written to db
# Request 121
# No tweets fetched

# %% [markdown]
# https://twitter.com/sercanoksak/status/1246154630175875076

# %%
tweets_db.delete_many({'hashtag_id': '#gerçekfikrine'})

# %%
tweets_db.find_one({'id': 1250861860175450112})

# %%
max_id = 1251223630245232653 - 1

# %%
1252719203779567619 < 1251276936220901376
# Out:
# False

# %%
tweets_db = db.tweets_for_sentiment

# %%
tweet_search_continue = True
check_all_for_dup = True
hashtag_id = 'covid OR covid19 OR korona OR koronavirüs OR koronavırus OR kovid'
max_id = None
request_number = 0

# %%
f = open('conflicts.txt', 'a+')

while tweet_search_continue:
    
    print("Request {}".format(request_number))
    
    request_number += 1
    
    tweets = api.search(q=hashtag_id, count=100, lang="tr", max_id=max_id, tweet_mode="extended")
    
    if len(tweets) == 0:
        print("No tweets fetched")
        break
    
    tweets = [tweet._json for tweet in tweets]

    print("Number of tweets {}".format(len(tweets)))
    
    tweets_filtered = []
    for tweet in tweets:
        
        # Check if it is a RT, if RT do no include
        if tweet['full_text'].startswith('RT'):
            continue
        
        no_conflict = True
        
        if no_conflict:
            tweets_filtered.append(tweet)
    
    if len(tweets_filtered) == 0:
        # Means all the fetched tweets are unfiltered as of conflict
        print("No tweets to write database")
        
        last_tweet = tweets[len(tweets)-1]
        max_id = last_tweet['id'] - 1
    
    else:
        print("{} tweets written to db".format(len(tweets_filtered)))
        try:
            tweets_db.insert_many([reshape_tweet(tweet, hashtag_id) for tweet in tweets_filtered])
        except BulkWriteError as bwe:
            pprint(bwe.details)
            raise

        last_tweet = tweets_filtered[len(tweets_filtered)-1]
        max_id = last_tweet['id'] - 1

f.close()
# Out:
# Request 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fa42e70d320e> in <module>
#       7     request_number += 1
#       8
# ----> 9     tweets = api.search(q=hashtag_id, count=100, lang="tr", max_id=max_id, tweet_mode="extended")
#      10
#      11     if len(tweets) == 0:
#
# NameError: name 'api' is not defined
